# %% [markdown]
# # Libraries

# %%
import numpy as np # linear algebra
from math import ceil # 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from scipy.stats import skew 
from sklearn.preprocessing import (
                                    LabelEncoder,
                                    StandardScaler,
                                    RobustScaler,
                                    MinMaxScaler,
                                    PolynomialFeatures)
from sklearn.impute import KNNImputer
from sklearn.feature_selection import mutual_info_regression
from sklearn.model_selection import cross_validate, ShuffleSplit, LeaveOneOut
from sklearn.linear_model import LinearRegression, Lasso, Ridge, RidgeCV
from sklearn.metrics import root_mean_squared_log_error, mean_squared_log_error, make_scorer

from collections import defaultdict # used to store the label encoder of multiple features and inverse_transform
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from typing import List, Union

# %% [markdown]
# ## functions

# %%
def calc_mi_scores(X: pd.DataFrame, y: pd.DataFrame, discrete_features: List[str]) -> pd.Series:
    """
    calculates MI (mutual information) scores, requires a list of discrete/categorical features
    Inputs
        X: df with features
        y: df with results (true values) 
        discrete_features: list of names of categorical featues (column names of X dataframe)
    Outputs
        mi_scores: MI score for all the features as pd.Series
    """
    mi_scores: np.ndarray = mutual_info_regression(X, y, discrete_features=discrete_features)
    mi_scores: pd.Series = pd.Series(mi_scores, name="MI scores", index=X.columns)
    mi_scores: pd.Series = mi_scores.sort_values(ascending=False)
    return mi_scores

# %%
def interactions_gen(X: pd.DataFrame, discrete_features: List[str]) -> tuple([pd.DataFrame, List[str]]) : 
    """
    Generates pair-wise (2nd degree) interactions of all features including column name
    Many of these interactions are not relevant for prediction (MI score = 0) and must be later removed using interaction_sel_gen()  
    Adds the newly-generated interactions ONLY IF BOTH original/parent features are categorials/dicrete
    Required for interaction_gen_sel()
    Inputs
        X: DataFrame with either the features, e.g. X_train or X_test
        discrete_features: list with names of discrete/categorical features
    Outputs
        X_interactions: DataFrame with original features (linear terms) and interactions (2nd degree)
        updated_discrete_features: list with categorical/discrete features (originals + interactions)
    """

    col_names: List[str] = []
    updated_discrete_features = discrete_features.copy()
    
    col_names.extend(X.columns.to_list())
    for pair in combinations(X.columns, 2):
        new_ft_name = pair[0] + 'x' + pair[1] # name of the feature resulting from the interaction, to be used as column name
        col_names.append(new_ft_name)

        if pair[0] in discrete_features and pair[1] in discrete_features:
            updated_discrete_features.append(new_ft_name) #add new feature to internal categorical_ft list, if both are categorical
    
    # generates the 2nd degree interactions and returns them togehter with the linear terms (features) in the first p columns (p = nr of features)
    lin_int: np.ndarray = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False).fit_transform(X)
    
    X_interactions = pd.DataFrame(data=lin_int, columns=col_names, index=X.index) # all of the linears + interactions before removing the low-MI features    
    
    return X_interactions, updated_discrete_features

# %%
def interaction_gen_sel(X_train: pd.DataFrame, X_test: pd.DataFrame, y_train: pd.Series, discrete_features: List[str]) -> tuple([pd.DataFrame, pd.DataFrame, List[str]]):
    """
    Generates & selects interaction features (2nd degree) with an MI score above the threshold defined below,
    initially interactions form all features are generated then, those that are non-informative are removed.
    Mutual information (MI score) is used to select the interaction features above the threshold defined below
    Inputs
        X_train: train DataFrame with the scaled features, e.g. X_train
        X_test: test DataFrame with scaled features, e.g. X_test
        discrete_features: list with names of discrete/categorical features
        y_train: DataFrame with results (true values) 
    Outputs
        X_train: train DataFrame with original features plus selected interaction features
        X_test: test DataFrame with original features plus selected interaction features
        updated_discrete_features: list with selected categorical/discrete features (originals + interactions)
    """
    
    num_original_ft: int = X_train.shape[1] # saved for later reference to select only interaction features and keep all original features
    X_train_linears: pd.DataFrame = X_train.copy() # saves a copy with only the original (linear features) for later update

    
    ## GENERATION ##
    
    X_train, updated_discrete_features = interactions_gen(X_train, discrete_features)
    X_test, _ = interactions_gen(X_test, discrete_features)    

    
    ## SELECTION ##
    
    threshold: float = 1e-2 # MI threshold to drop the newly-generated interaction features
    mi_scores: pd.Series = calc_mi_scores(X_train, y_train, X_train.columns.get_indexer(updated_discrete_features))
    
    
    df = pd.DataFrame(index=X_train.index, columns=X_train.columns) #placeholder df to be populated later
    df.update(
        X_train.drop(columns=mi_scores[mi_scores < threshold].index)) #add features above the MI threshold
    df.update(
        X_train_linears) #add the remaining linear features below the MI threshold
    X_train: pd.DataFrame = df.dropna(axis=1)
    X_train = X_train.astype('float') #cast df as float (previously being casted as object)
    
    
    # remove the feature's name with an MI score below the threshold from the list of categorical/discrete features 
    for item in mi_scores[mi_scores < threshold].index.to_list():
        try: updated_discrete_features.remove(item)
        except ValueError: pass

    # adjust the X_test to match X_train
    X_test = X_test[X_train.columns]


    return X_train, X_test, updated_discrete_features

# %% [markdown]
# ## working dir

# %%
import os
for dirname, _, filenames in os.walk('./input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./input/data_description.txt
# ./input/sample_submission.csv
# ./input/test.csv
# ./input/train.csv

# %% [markdown]
# # data import EDA

# %%
train = pd.read_csv(r'./input/train.csv')\
    .drop(columns='Id') # 'Id' was just a repetion of the index
y_train = train.pop('SalePrice')
test = pd.read_csv(r'./input/test.csv')\
    .drop(columns='Id') # 'Id' was just a repetion of the index

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   object
#  21  RoofMatl       1460 non-null   object
#  22  Exterior1st    1460 non-null   object
#  23  Exterior2nd    1460 non-null   object
#  24  MasVnrType     588 non-null    object
#  25  MasVnrArea     1452 non-null   float64
#  26  ExterQual      1460 non-null   object
#  27  ExterCond      1460 non-null   object
#  28  Foundation     1460 non-null   object
#  29  BsmtQual       1423 non-null   object
#  30  BsmtCond       1423 non-null   object
#  31  BsmtExposure   1422 non-null   object
#  32  BsmtFinType1   1423 non-null   object
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1422 non-null   object
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   object
#  39  HeatingQC      1460 non-null   object
#  40  CentralAir     1460 non-null   object
#  41  Electrical     1459 non-null   object
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   object
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   object
#  55  Fireplaces     1460 non-null   int64
#  56  FireplaceQu    770 non-null    object
#  57  GarageType     1379 non-null   object
#  58  GarageYrBlt    1379 non-null   float64
#  59  GarageFinish   1379 non-null   object
#  60  GarageCars     1460 non-null   int64
#  61  GarageArea     1460 non-null   int64
#  62  GarageQual     1379 non-null   object
#  63  GarageCond     1379 non-null   object
#  64  PavedDrive     1460 non-null   object
#  65  WoodDeckSF     1460 non-null   int64
#  66  OpenPorchSF    1460 non-null   int64
#  67  EnclosedPorch  1460 non-null   int64
#  68  3SsnPorch      1460 non-null   int64
#  69  ScreenPorch    1460 non-null   int64
#  70  PoolArea       1460 non-null   int64
#  71  PoolQC         7 non-null      object
#  72  Fence          281 non-null    object
#  73  MiscFeature    54 non-null     object
#  74  MiscVal        1460 non-null   int64
#  75  MoSold         1460 non-null   int64
#  76  YrSold         1460 non-null   int64
#  77  SaleType       1460 non-null   object
#  78  SaleCondition  1460 non-null   object
# dtypes: float64(3), int64(33), object(43)
# memory usage: 901.2+ KB

# %%
train.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
print('# of obj columns:', train.select_dtypes(include='O').columns.size) 
print('# of num columns:', train.select_dtypes(exclude='O').columns.size)
# Out:
# # of obj columns: 43
# # of num columns: 36

# %% [markdown]
# ## price histogram

# %%
sns.histplot(y_train)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# # Enconding of categoricals

# %% [markdown]
# ## ordinal enconding, hard-coded
# for e.g. quality ratings (Excellent, Good, Fair, Poor, ...) and etc...

# %%
categorical_ft = [] # list to collect the name of categorical features (discontiuous features both ordinal ratings and boolean features)

# %%
#ordinal enconding, hard-coded for e.g. quality categories (Excellent, Good, Fair, Poor, etc...)
ord_ft = {
    'LotShape': {'Reg': 1, 'IR1': 2, 'IR2': 3,'IR3': 4},
    'LandSlope': {'Gtl': 1, 'Mod': 2, 'Sev': 3},
    'ExterQual': {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4,'Po': 5},
    'ExterCond': {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4,'Po': 5},
    'BsmtQual': {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4,'Po': 5,'NA': 6}, 
    'BsmtCond': {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4,'Po': 5,'NA': 6},
    'BsmtExposure': {'Gd': 1, 'Av': 2, 'Mn': 3, 'No': 4,'NA': 5},
    'BsmtFinType1': {'GLQ': 1, 'ALQ': 2, 'BLQ': 3, 'Rec': 4,'LwQ': 5,'Unf': 6,'NA': 7},
    'BsmtFinType2': {'GLQ': 1, 'ALQ': 2, 'BLQ': 3, 'Rec': 4,'LwQ': 5,'Unf': 6,'NA': 7},
    'HeatingQC': {'Ex': 1, 'Gd': 2, 'TA': 3,'Fa': 4, 'Po': 5},
    'Electrical': {'SBrkr': 1, 'FuseA': 2, 'FuseF': 3, 'FuseP': 4,'Mix': 5},
    'KitchenQual': {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4,'Po': 5},
    'Functional': {'Typ': 1, 'Min1': 2, 'Min2': 3, 'Mod': 4,'Maj1': 5,'Maj2': 6,'Sev': 7,'Sal': 8},
    'FireplaceQu': {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4,'Po': 5,'NA': 6},
    'GarageFinish': {'Fin': 1, 'RFn': 2, 'Unf': 3, 'NA': 4},
    'GarageQual': {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4,'Po': 5,'NA': 6},
    'GarageCond': {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4,'Po': 5,'NA': 6},
    'PavedDrive': {'Y': 1, 'P': 2, 'N': 3},
    'PoolQC': {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4,'NA': 5},
    'Fence': {'GdPrv': 1, 'MnPrv': 2, 'GdWo': 3, 'MnWw': 4, 'NA': 5},
    'SaleCondition': {'Normal': 1, 'Abnorml': 2, 'AdjLand': 3, 'Alloca': 4, 'Family': 5, 'Partial': 6},
}

train[list(ord_ft)] = train[list(ord_ft)].fillna('NA')
test[list(ord_ft)] = test[list(ord_ft)].fillna('NA')

train.replace(ord_ft, inplace=True)
test.replace(ord_ft, inplace=True)

train.replace('NA', np.nan, inplace=True)
test.replace('NA', np.nan, inplace=True)
# Out:
# /tmp/ipykernel_95049/1488741958.py:29: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train.replace(ord_ft, inplace=True)
# /tmp/ipykernel_95049/1488741958.py:30: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test.replace(ord_ft, inplace=True)
# /tmp/ipykernel_95049/1488741958.py:32: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train.replace('NA', np.nan, inplace=True)
# /tmp/ipykernel_95049/1488741958.py:33: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test.replace('NA', np.nan, inplace=True)

# %%
# new column for Basement Yes/No?
train['Bsmt'] = train['BsmtCond'].isna().astype(int)
test['Bsmt'] = test['BsmtCond'].isna().astype(int)

# new column for Garage Yes/No?
train['Garage'] = train['GarageFinish'].isna().astype(int)
test['Garage'] = test['GarageFinish'].isna().astype(int)

# %%
# unfolds the 'MiscFeature' into separate columns and drops it, keeps the misc feature name to add to ccategorical_ft list 
misc_names = []
for misc_feat in train['MiscFeature'].dropna().unique():
    train[misc_feat] = (train['MiscFeature'] == misc_feat).astype(int)
    test[misc_feat] = (test['MiscFeature'] == misc_feat).astype(int)
    misc_names.append(misc_feat)

train.drop(columns='MiscFeature', inplace=True)
test.drop(columns='MiscFeature', inplace=True)

# %%
categorical_ft.extend(ord_ft.keys())
categorical_ft.extend(['Bsmt', 'Garage'])
categorical_ft.extend(misc_names)

# %%
print('# of obj columns:', train.select_dtypes(include='O').columns.size) 
print('# of num columns:', train.select_dtypes(exclude='O').columns.size)
# Out:
# # of obj columns: 21
# # of num columns: 63

# %% [markdown]
# ## label encoding
# for non-inteligible, unknown features that can't be transformed to an ordered qualitative sequence

# %%
train_cat = train.select_dtypes(include='O')
test_cat = test.select_dtypes(include='O')
train_cat
# Out:
#      MSZoning Street Alley LandContour Utilities LotConfig Neighborhood  \
# 0          RL   Pave   NaN         Lvl    AllPub    Inside      CollgCr
# 1          RL   Pave   NaN         Lvl    AllPub       FR2      Veenker
# 2          RL   Pave   NaN         Lvl    AllPub    Inside      CollgCr
# 3          RL   Pave   NaN         Lvl    AllPub    Corner      Crawfor
# 4          RL   Pave   NaN         Lvl    AllPub       FR2      NoRidge
# ...       ...    ...   ...         ...       ...       ...          ...
# 1455       RL   Pave   NaN         Lvl    AllPub    Inside      Gilbert
# 1456       RL   Pave   NaN         Lvl    AllPub    Inside       NWAmes
# 1457       RL   Pave   NaN         Lvl    AllPub    Inside      Crawfor
# 1458       RL   Pave   NaN         Lvl    AllPub    Inside        NAmes
# 1459       RL   Pave   NaN         Lvl    AllPub    Inside      Edwards
#
#      Condition1 Condition2 BldgType  ... RoofStyle RoofMatl Exterior1st  \
# 0          Norm       Norm     1Fam  ...     Gable  CompShg     VinylSd
# 1         Feedr       Norm     1Fam  ...     Gable  CompShg     MetalSd
# 2          Norm       Norm     1Fam  ...     Gable  CompShg     VinylSd
# 3          Norm       Norm     1Fam  ...     Gable  CompShg     Wd Sdng
# 4          Norm       Norm     1Fam  ...     Gable  CompShg     VinylSd
# ...         ...        ...      ...  ...       ...      ...         ...
# 1455       Norm       Norm     1Fam  ...     Gable  CompShg     VinylSd
# 1456       Norm       Norm     1Fam  ...     Gable  CompShg     Plywood
# 1457       Norm       Norm     1Fam  ...     Gable  CompShg     CemntBd
# 1458       Norm       Norm     1Fam  ...       Hip  CompShg     MetalSd
# 1459       Norm       Norm     1Fam  ...     Gable  CompShg     HdBoard
#
#      Exterior2nd MasVnrType Foundation Heating CentralAir GarageType SaleType
# 0        VinylSd    BrkFace      PConc    GasA          Y     Attchd       WD
# 1        MetalSd        NaN     CBlock    GasA          Y     Attchd       WD
# 2        VinylSd    BrkFace      PConc    GasA          Y     Attchd       WD
# 3        Wd Shng        NaN     BrkTil    GasA          Y     Detchd       WD
# 4        VinylSd    BrkFace      PConc    GasA          Y     Attchd       WD
# ...          ...        ...        ...     ...        ...        ...      ...
# 1455     VinylSd        NaN      PConc    GasA          Y     Attchd       WD
# 1456     Plywood      Stone     CBlock    GasA          Y     Attchd       WD
# 1457     CmentBd        NaN      Stone    GasA          Y     Attchd       WD
# 1458     MetalSd        NaN     CBlock    GasA          Y     Attchd       WD
# 1459     HdBoard        NaN     CBlock    GasA          Y     Attchd       WD
#
# [1460 rows x 21 columns]

# %%
d = defaultdict(LabelEncoder) # structure to add the label encoders for each categorical feature (df column)

# Encoding the variable
train_cat_enc = train_cat.apply(lambda x: d[x.name].fit_transform(x))
test_cat_enc = test_cat.apply(lambda x: d[x.name].fit_transform(x))
train_cat_enc

# Inverse the encoded
#train_cat_enc.apply(lambda x: d[x.name].inverse_transform(x))
#test_cat_enc.apply(lambda x: d[x.name].inverse_transform(x))

# Using the dictionary to label future data
#new_data.apply(lambda x: d[x.name].transform(x))
# Out:
#       MSZoning  Street  Alley  LandContour  Utilities  LotConfig  \
# 0            3       1      2            3          0          4
# 1            3       1      2            3          0          2
# 2            3       1      2            3          0          4
# 3            3       1      2            3          0          0
# 4            3       1      2            3          0          2
# ...        ...     ...    ...          ...        ...        ...
# 1455         3       1      2            3          0          4
# 1456         3       1      2            3          0          4
# 1457         3       1      2            3          0          4
# 1458         3       1      2            3          0          4
# 1459         3       1      2            3          0          4
#
#       Neighborhood  Condition1  Condition2  BldgType  ...  RoofStyle  \
# 0                5           2           2         0  ...          1
# 1               24           1           2         0  ...          1
# 2                5           2           2         0  ...          1
# 3                6           2           2         0  ...          1
# 4               15           2           2         0  ...          1
# ...            ...         ...         ...       ...  ...        ...
# 1455             8           2           2         0  ...          1
# 1456            14           2           2         0  ...          1
# 1457             6           2           2         0  ...          1
# 1458            12           2           2         0  ...          3
# 1459             7           2           2         0  ...          1
#
#       RoofMatl  Exterior1st  Exterior2nd  MasVnrType  Foundation  Heating  \
# 0            1           12           13           1           2        1
# 1            1            8            8           3           1        1
# 2            1           12           13           1           2        1
# 3            1           13           15           3           0        1
# 4            1           12           13           1           2        1
# ...        ...          ...          ...         ...         ...      ...
# 1455         1           12           13           3           2        1
# 1456         1            9           10           2           1        1
# 1457         1            5            5           3           4        1
# 1458         1            8            8           3           1        1
# 1459         1            6            6           3           1        1
#
#       CentralAir  GarageType  SaleType
# 0              1           1         8
# 1              1           1         8
# 2              1           1         8
# 3              1           5         8
# 4              1           1         8
# ...          ...         ...       ...
# 1455           1           1         8
# 1456           1           1         8
# 1457           1           1         8
# 1458           1           1         8
# 1459           1           1         8
#
# [1460 rows x 21 columns]

# %%
train_clean = pd.concat([train.select_dtypes(exclude='O'), train_cat_enc], axis=1)
test_clean = pd.concat([test.select_dtypes(exclude='O'), test_cat_enc], axis=1)

# %%
train_clean.select_dtypes(include=float)
# Out:
#       LotFrontage  MasVnrArea  Electrical  GarageYrBlt
# 0            65.0       196.0         1.0       2003.0
# 1            80.0         0.0         1.0       1976.0
# 2            68.0       162.0         1.0       2001.0
# 3            60.0         0.0         1.0       1998.0
# 4            84.0       350.0         1.0       2000.0
# ...           ...         ...         ...          ...
# 1455         62.0         0.0         1.0       1999.0
# 1456         85.0       119.0         1.0       1978.0
# 1457         66.0         0.0         1.0       1941.0
# 1458         68.0         0.0         2.0       1950.0
# 1459         75.0         0.0         1.0       1965.0
#
# [1460 rows x 4 columns]

# %% [markdown]
# # Impute of missing values NaN

# %%
# frequency of NaN in X_train
train_clean.isna().sum().sort_values(ascending=False)[:10]/train.shape[0]
# Out:
# LotFrontage    0.177397
# GarageYrBlt    0.055479
# MasVnrArea     0.005479
# Electrical     0.000685
# MoSold         0.000000
# Othr           0.000000
# Gar2           0.000000
# Shed           0.000000
# Garage         0.000000
# Bsmt           0.000000
# dtype: float64

# %%
# frequency of NaN in X_test
test_clean.isna().sum().sort_values(ascending=False)[:10]/train.shape[0]
# Out:
# LotFrontage     0.155479
# GarageYrBlt     0.053425
# MasVnrArea      0.010274
# BsmtHalfBath    0.001370
# Functional      0.001370
# BsmtFullBath    0.001370
# BsmtFinSF2      0.000685
# BsmtUnfSF       0.000685
# TotalBsmtSF     0.000685
# GarageCars      0.000685
# dtype: float64

# %%
impute_cols_train = train_clean.columns[train_clean.isna().any()]
impute_cols_test = test_clean.columns[test_clean.isna().any()]

print(impute_cols_test)
print(impute_cols_train)
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual',
#        'Functional', 'GarageYrBlt', 'GarageCars', 'GarageArea'],
#       dtype='object')
# Index(['LotFrontage', 'MasVnrArea', 'Electrical', 'GarageYrBlt'], dtype='object')

# %%
imputer = KNNImputer(n_neighbors=20, weights='distance')
train_imp = pd.DataFrame(data=imputer.fit_transform(train_clean), index=train_clean.index, columns=train_clean.columns)
train_clean = train_imp
test_imp = pd.DataFrame(data=imputer.fit_transform(test_clean), index=test_clean.index, columns=test_clean.columns)
test_clean = train_imp

# %%
train_clean.isna().any(axis=None)
# Out:
# False

# %%
test_clean.isna().any(axis=None)
# Out:
# False

# %% [markdown]
# # Feature scaling

# %%
# standard scaling

# %%
scaler = MinMaxScaler()
#scaler = StandardScaler()
#scaler = RobustScaler()
scaler.fit(train_clean);

# %%
X_train = pd.DataFrame(scaler.transform(train_clean), index=train_clean.index, columns=train_clean.columns)
X_test = pd.DataFrame(scaler.transform(test_clean), index=test_clean.index, columns=test_clean.columns)

# %% [markdown]
# ## ft skewness assessment

# %%
ft_skew = skew(X_train, axis=0)

# %%
fig, ax = plt.subplots()
ax.plot(ft_skew)
ax.set_xlabel('feature idx ( - )')
ax.set_ylabel('skewness ( - )')
# Out:
# Text(0, 0.5, 'skewness ( - )')

# %%
ncols = 6
ft_n = X_train.shape[1]
nrows = ceil(ft_n/ncols)
fig, axs = plt.subplots(nrows, ncols, figsize=(15, 2.5*nrows))
for i, ax in enumerate(axs.flat):
    if i > ft_n - 1: break 
    ax.hist(X_train.iloc[:,i], bins=20, cumulative=False)
    ax.text(0.7, 0.8, 'FP skewness:\n{:.3g}'.format(ft_skew[i]), transform=ax.transAxes, 
            horizontalalignment='center', fontsize=10,
            color='red' if np.isnan(ft_skew[i]) else 'black')
    ax.set_title(X_train.columns[i])
plt.tight_layout()

# %%
X_train.drop(columns=['Bsmt', 'Garage'],inplace=True)
X_test.drop(columns=['Bsmt', 'Garage'],inplace=True)

# %%
d=dict()
for col in X_train.columns:
    d.update({
        col:
        100-np.count_nonzero(np.histogram(X_train[col], bins=100)[0])
    })
s = pd.Series(d)
print('top features with zero-observations bins (out of 100 bins):') 
s.sort_values(ascending=False).head(15)
# Out:
# top features with zero-observations bins (out of 100 bins):
# Gar2            98
# Shed            98
# Othr            98
# TenC            98
# Street          98
# CentralAir      98
# Utilities       98
# PavedDrive      97
# HalfBath        97
# BsmtHalfBath    97
# Alley           97
# LandSlope       97
# BsmtFullBath    96
# GarageFinish    96
# Fireplaces      96
# dtype: int64

# %% [markdown]
# -- COMMENT --
#
# - two features (Garage, Bsmt) are uniformative (skewness = nan, all observations have the same value)
#     - these features need to be dropped
# - many features are binary or low-difference qualitative rating with also high skewness
#     -> consider a different cross-validation method (maybe LPO Leave P Out??-> did not help, still negative values being predicted)

# %% [markdown]
# # Interaction generation & selection

# %%
X_train.dtypes
# Out:
# MSSubClass     float64
# LotFrontage    float64
# LotArea        float64
# LotShape       float64
# LandSlope      float64
#                 ...
# Foundation     float64
# Heating        float64
# CentralAir     float64
# GarageType     float64
# SaleType       float64
# Length: 82, dtype: object

# %%
print('Dimensions')
print('{}\t\t{}'.format('X_train', X_train.shape))
print('{}\t\t{}'.format('X_test', X_test.shape))
print('{}\t{}'.format('categorical_ft', len(categorical_ft)))
# Out:
# Dimensions
# X_train		(1460, 82)
# X_test		(1460, 82)
# categorical_ft	27

# %%
X_train, X_test, categorical_ft = interaction_gen_sel(X_train, X_test, y_train, categorical_ft)

# %%
print('Dimensions')
print('{}\t\t{}'.format('X_train', X_train.shape))
print('{}\t\t{}'.format('X_test', X_test.shape))
print('{}\t{}'.format('categorical_ft', len(categorical_ft)))
# Out:
# Dimensions
# X_train		(1460, 1977)
# X_test		(1460, 1977)
# categorical_ft	157

# %%
X_train.isna().any(axis=None)
# Out:
# False

# %%
X_test.isna().any(axis=None)
# Out:
# False

# %%
X_train.dtypes
# Out:
# MSSubClass               float64
# LotFrontage              float64
# LotArea                  float64
# LotShape                 float64
# LandSlope                float64
#                           ...
# FoundationxSaleType      float64
# HeatingxCentralAir       float64
# HeatingxGarageType       float64
# CentralAirxGarageType    float64
# GarageTypexSaleType      float64
# Length: 1977, dtype: object

# %%
X_test.dtypes
# Out:
# MSSubClass               float64
# LotFrontage              float64
# LotArea                  float64
# LotShape                 float64
# LandSlope                float64
#                           ...
# FoundationxSaleType      float64
# HeatingxCentralAir       float64
# HeatingxGarageType       float64
# CentralAirxGarageType    float64
# GarageTypexSaleType      float64
# Length: 1977, dtype: object

# %% [markdown]
# # Linear Regression

# %%
linreg = LinearRegression()

# %%
lasso = Lasso(alpha=1)

# %%
linreg_results = cross_validate(linreg, X_train, y_train,
                                #cv=5,
                                cv=ShuffleSplit(n_splits=10, test_size=.25, random_state=0),
                                #scoring='neg_root_mean_squared_log_error',
                                scoring='mean_squared_log_error',
                                return_estimator=True)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 linreg_results = cross_validate(linreg, X_train, y_train,
#       2                                 #cv=5,
#       3                                 cv=ShuffleSplit(n_splits=10, test_size=.25, random_state=0),
#       4                                 #scoring='neg_root_mean_squared_log_error',
#       5                                 scoring='mean_squared_log_error',
#       6                                 return_estimator=True)
#
# File ~/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:203, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     200 to_ignore += ["self", "cls"]
#     201 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 203 validate_parameter_constraints(
#     204     parameter_constraints, params, caller_name=func.__qualname__
#     205 )
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
#
# File ~/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:95, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      89 else:
#      90     constraints_str = (
#      91         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      92         f" {constraints[-1]}"
#      93     )
# ---> 95 raise InvalidParameterError(
#      96     f"The {param_name!r} parameter of {caller_name} must be"
#      97     f" {constraints_str}. Got {param_val!r} instead."
#      98 )
#
# InvalidParameterError: The 'scoring' parameter of cross_validate must be a str among {'f1_weighted', 'jaccard_weighted', 'matthews_corrcoef', 'neg_median_absolute_error', 'balanced_accuracy', 'positive_likelihood_ratio', 'jaccard', 'r2', 'jaccard_macro', 'precision', 'neg_negative_likelihood_ratio', 'roc_auc_ovo_weighted', 'max_error', 'fowlkes_mallows_score', 'recall', 'top_k_accuracy', 'f1_samples', 'explained_variance', 'neg_mean_absolute_error', 'recall_samples', 'accuracy', 'recall_macro', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_log_error', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'normalized_mutual_info_score', 'v_measure_score', 'homogeneity_score', 'neg_root_mean_squared_log_error', 'adjusted_rand_score', 'f1', 'precision_weighted', 'neg_root_mean_squared_error', 'rand_score', 'precision_micro', 'completeness_score', 'roc_auc', 'average_precision', 'precision_samples', 'precision_macro', 'mutual_info_score', 'jaccard_samples', 'neg_log_loss', 'recall_micro', 'recall_weighted', 'neg_brier_score', 'neg_mean_squared_error', 'adjusted_mutual_info_score', 'neg_mean_gamma_deviance', 'f1_micro', 'roc_auc_ovr', 'neg_mean_poisson_deviance', 'jaccard_micro', 'f1_macro'}, a callable, an instance of 'list', an instance of 'tuple', an instance of 'dict' or None. Got 'mean_squared_log_error' instead.

# %%
lasso_results = cross_validate(lasso, X_train, y_train,
                                #cv=5,
                                cv=ShuffleSplit(n_splits=10, test_size=.25, random_state=0),
                                #scoring='neg_root_mean_squared_log_error',
                                scoring='neg_root_mean_squared_log_error',
                                return_estimator=True)
# Out:
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_regression.py", line 759, in root_mean_squared_log_error
#     raise ValueError(
# ValueError: Root Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.204e+09, tolerance: 6.458e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.130e+09, tolerance: 6.420e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_regression.py", line 759, in root_mean_squared_log_error
#     raise ValueError(
# ValueError: Root Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_regression.py", line 759, in root_mean_squared_log_error
#     raise ValueError(
# ValueError: Root Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.243e+09, tolerance: 6.500e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_regression.py", line 759, in root_mean_squared_log_error
#     raise ValueError(
# ValueError: Root Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.008e+09, tolerance: 6.423e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_regression.py", line 759, in root_mean_squared_log_error
#     raise ValueError(
# ValueError: Root Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.205e+11, tolerance: 7.188e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_regression.py", line 759, in root_mean_squared_log_error
#     raise ValueError(
# ValueError: Root Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:993: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 982, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 253, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/metrics/_regression.py", line 759, in root_mean_squared_log_error
#     raise ValueError(
# ValueError: Root Mean Squared Logarithmic Error cannot be used when targets contain negative values.
#
#   warnings.warn(
# /home/dmartins/anaconda3/envs/ds312/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.339e+09, tolerance: 6.799e+08
#   model = cd_fast.enet_coordinate_descent(

# %%
lasso_results
# Out:
# {'fit_time': array([0.01902676, 0.08167028, 0.06169724, 0.01203108, 0.06215739,
#         0.06230569, 0.00859904, 0.05310273, 0.00930405, 0.06391764]),
#  'score_time': array([0.00369143, 0.00131774, 0.00149107, 0.00130224, 0.00156355,
#         0.00126719, 0.00111485, 0.00141072, 0.00123239, 0.00146747]),
#  'estimator': [Lasso(alpha=1),
#   Lasso(alpha=1),
#   Lasso(alpha=1),
#   Lasso(alpha=1),
#   Lasso(alpha=1),
#   Lasso(alpha=1),
#   Lasso(alpha=1),
#   Lasso(alpha=1),
#   Lasso(alpha=1),
#   Lasso(alpha=1)],
#  'test_score': array([        nan, -0.17737922,         nan,         nan,         nan,
#         -0.26039494,         nan,         nan,         nan, -0.18583541])}

# %%
linreg_results
# Out:
# {'fit_time': array([0.0047152 , 0.00351715, 0.00312448, 0.00345778, 0.0035162 ,
#         0.00336146, 0.00349212, 0.00311732, 0.0030477 , 0.00332308]),
#  'score_time': array([0.00241184, 0.00116682, 0.00129843, 0.00156093, 0.00133586,
#         0.00133777, 0.00134778, 0.0012331 , 0.00124764, 0.00109339]),
#  'estimator': [LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression(),
#   LinearRegression()],
#  'test_score': array([        nan, -0.17741239,         nan,         nan,         nan,
#         -0.26067492,         nan,         nan,         nan, -0.18592008])}

# %% [markdown]
# ## Sandbox

# %% [markdown]
# # Notes
#
# - [x] Feature engineering
#     - [x] categorical encoding
#     - [x] imputation
#     - [x] feature scaling
#     - [x] interaction (2nd deg.)
#         - [x] fix the the interaction_gen_sel() because some of the original (linear) features are being removed
#
# - [ ] Models
#     - [ ] add multi linear regression
#
#         - __!! prediction is delivering negative prices!!__
#             - [ ] check either MinMaxScaler
#             - [ ] or RobustScaler to get rid of outliers
#     - [ ] use GridSearchCV for {Lasso, Rigde} {??? 1e-3, ..., 1e+3 ???}
#     - [ ] principal componant regression
#     - [ ] ARD regression
#     - [ ] Bayesian regression
#     - [ ] ANN
#
# ### Misc
# - [x] add type hints/annotations to functions and code boundaries
